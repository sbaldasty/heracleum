# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../out/poisoneffect.csv")
df.head()
# Out:
#    n_clients  n_rounds  n_corrupt_clients         attack      loss  accuracy
# 0         10        30                  0  Sign flipping  1.087309    0.6180
# 1         10        30                  1  Sign flipping  1.786048    0.4713
# 2         10        30                  2  Sign flipping  2.229228    0.1900
# 3         10        30                  3  Sign flipping  2.302625    0.1000
# 4         10        30                  4  Sign flipping  2.302636    0.1000

# %%
n_clients = df['n_clients'].iloc[0]
n_clients
# Out:
# 10

# %%
attacks = list(df['attack'].unique())
attacks
# Out:
# ['Sign flipping', 'Scaling (factor=2.0)', 'Gaussian noise (mu=0.0, sigma=0.5)']

# %%
for attack in attacks:
    subdf = df[df['attack'] == attack]
    plt.plot(subdf['n_corrupt_clients'], subdf['accuracy'], label=attack)

plt.title(f'CIFAR-10 data set with {n_clients} clients')
plt.xlabel("# Corrupt clients")
plt.ylabel("Model accuracy")
plt.legend()
plt.tight_layout()
plt.show()
