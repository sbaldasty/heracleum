# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../out/poisoneffect.csv")
df.head()
# Out:
#    n_clients  n_rounds  n_corrupt_clients      loss  accuracy
# 0         10        20                  0  1.903066    0.2887
# 1         10        20                  1  2.056953    0.2594
# 2         10        20                  2  2.201337    0.1617
# 3         10        20                  3  2.287520    0.1597
# 4         10        20                  4  2.303077    0.1000

# %%
n_clients = df['n_clients'].iloc[0]
n_clients
# Out:
# 10

# %%
plt.plot(df['n_corrupt_clients'], df['accuracy'], label='Sign flipping')
plt.title(f'CIFAR-10 data set with {n_clients} clients')
plt.xlabel("# Corrupt clients")
plt.ylabel("Model accuracy")
plt.legend()
plt.tight_layout()
plt.show()
